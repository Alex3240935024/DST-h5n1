# %% [markdown]
# # Reading In the data from an excel file

# %%
library("readxl")
library(tidyverse)
library(dplyr)
#install.packages("writexl")
library(writexl)
#read_excel("fatality rates h5n1.xlsx")
#getwd()

fat_data <- read_excel("fatality rates h5n1.xlsx")
fat_data
# Out:
#    Year Cases Deaths Fatality Rate Sample Size Years from 2024
# 1  2003   4    4     1.0000000       4         21
# 2  2004  46   32     0.6956522      46         20
# 3  2005  98   43     0.4387755      98         19
# 4  2006 115   79     0.6869565     115         18
# 5  2007  88   59     0.6704545      88         17
# 6  2008  44   33     0.7500000      44         16
# 7  2009  73   32     0.4383562      73         15
# 8  2010  48   24     0.5000000      48         14
# 9  2011  62   34     0.5483871      62         13
# 10 2012  32   20     0.6250000      32         12
# 11 2013  39   25     0.6410256      39         11
# 12 2014  52   22     0.4230769      52         10
# 13 2015 145   42     0.2896552     145          9
# 14 2016  10    3     0.3000000      10          8
# 15 2017   4    2     0.5000000       4          7
# 16 2019   1    1     1.0000000       1          5
# 17 2020   1    0     0.0000000       1          4
# 18 2021   2    1     0.5000000       2          3
# 19 2022   6    1     0.1666667       6          2
# 20 2023   8    1     0.1250000       8          1

# %%
getwd()
# Out:
# [1] "C:/Users/Unsto/AppData/Local/Programs/Python/Python39/Scripts/Jupyter files/DST project in jup"

# %% [markdown]
# # Deriving weights from a data point

# %%
fat_data <- fat_data|>
  mutate(w_sample = `Sample Size` / 145) # Sample Size weight

fat_data <- fat_data|>
  mutate(w_recency = 2.718^(-0.1 *`Years from 2024`)) # Recency weight
#print(fat_data)
#write_xlsx(fat_data, "your_table.xlsx")

fat_data <- fat_data|>
  mutate(final_weight = w_sample * w_recency) # Final weight by combining
fat_data


#pmin(1, w_sample + w_recency)
# Out:
#    Year Cases Deaths Fatality Rate Sample Size Years from 2024 w_sample
# 1  2003   4    4     1.0000000       4         21              0.027586207
# 2  2004  46   32     0.6956522      46         20              0.317241379
# 3  2005  98   43     0.4387755      98         19              0.675862069
# 4  2006 115   79     0.6869565     115         18              0.793103448
# 5  2007  88   59     0.6704545      88         17              0.606896552
# 6  2008  44   33     0.7500000      44         16              0.303448276
# 7  2009  73   32     0.4383562      73         15              0.503448276
# 8  2010  48   24     0.5000000      48         14              0.331034483
# 9  2011  62   34     0.5483871      62         13              0.427586207
# 10 2012  32   20     0.6250000      32         12              0.220689655
# 11 2013  39   25     0.6410256      39         11              0.268965517
# 12 2014  52   22     0.4230769      52         10              0.358620690
# 13 2015 145   42     0.2896552     145          9              1.000000000
# 14 2016  10    3     0.3000000      10          8              0.068965517
# 15 2017   4    2     0.5000000       4          7              0.027586207
# 16 2019   1    1     1.0000000       1          5              0.006896552
# 17 2020   1    0     0.0000000       1          4              0.006896552
# 18 2021   2    1     0.5000000       2          3              0.013793103
# 19 2022   6    1     0.1666667       6          2              0.041379310
# 20 2023   8    1     0.1250000       8          1              0.055172414
#    w_recency final_weight Fatality_Category
# 1  0.1224831 0.003378844  F5
# 2  0.1353634 0.042942856  F4
# 3  0.1495981 0.101107673  F3
# 4  0.1653297 0.131123588  F4
# 5  0.1827157 0.110889545  F4
# 6  0.2019300 0.061275315  F4
# 7  0.2231649 0.112351967  F3
# 8  0.2466328 0.081643949  F3
# 9  0.2725685 0.116546544  F3
# 10 0.3012317 0.066478718  F4
# 11 0.3329091 0.089541055  F4
# 12 0.3679176 0.131942859  F3
# 13 0.4066076 0.406607601  F2
# 14 0.4493662 0.030990775  F2
# 15 0.4966213 0.013699899  F3
# 16 0.6065621 0.004183187  F5
# 17 0.6703478 0.004623089  F1
# 18 0.7408413 0.010218500  F3
# 19 0.8187477 0.033879216  F1
# 20 0.9048468 0.049922582  F1

# %% [markdown]
# # Assigning Each datapoint a fatality rate category

# %%
#write_xlsx(fat_data, "your_table.xlsx")

fat_data$Fatality_Category <- with(fat_data, ifelse(`Fatality Rate` <= 0.20, "F1",
                                  ifelse(`Fatality Rate` <= 0.4, "F2",
                                  ifelse(`Fatality Rate` <= 0.60, "F3",
                                  ifelse(`Fatality Rate` <= 0.80, "F4", "F5")))))

fat_data
# Out:
#    Year Cases Deaths Fatality Rate Sample Size Years from 2024 w_sample
# 1  2003   4    4     1.0000000       4         21              0.027586207
# 2  2004  46   32     0.6956522      46         20              0.317241379
# 3  2005  98   43     0.4387755      98         19              0.675862069
# 4  2006 115   79     0.6869565     115         18              0.793103448
# 5  2007  88   59     0.6704545      88         17              0.606896552
# 6  2008  44   33     0.7500000      44         16              0.303448276
# 7  2009  73   32     0.4383562      73         15              0.503448276
# 8  2010  48   24     0.5000000      48         14              0.331034483
# 9  2011  62   34     0.5483871      62         13              0.427586207
# 10 2012  32   20     0.6250000      32         12              0.220689655
# 11 2013  39   25     0.6410256      39         11              0.268965517
# 12 2014  52   22     0.4230769      52         10              0.358620690
# 13 2015 145   42     0.2896552     145          9              1.000000000
# 14 2016  10    3     0.3000000      10          8              0.068965517
# 15 2017   4    2     0.5000000       4          7              0.027586207
# 16 2019   1    1     1.0000000       1          5              0.006896552
# 17 2020   1    0     0.0000000       1          4              0.006896552
# 18 2021   2    1     0.5000000       2          3              0.013793103
# 19 2022   6    1     0.1666667       6          2              0.041379310
# 20 2023   8    1     0.1250000       8          1              0.055172414
#    w_recency final_weight Fatality_Category
# 1  0.1224831 0.003378844  F5
# 2  0.1353634 0.042942856  F4
# 3  0.1495981 0.101107673  F3
# 4  0.1653297 0.131123588  F4
# 5  0.1827157 0.110889545  F4
# 6  0.2019300 0.061275315  F4
# 7  0.2231649 0.112351967  F3
# 8  0.2466328 0.081643949  F3
# 9  0.2725685 0.116546544  F3
# 10 0.3012317 0.066478718  F4
# 11 0.3329091 0.089541055  F4
# 12 0.3679176 0.131942859  F3
# 13 0.4066076 0.406607601  F2
# 14 0.4493662 0.030990775  F2
# 15 0.4966213 0.013699899  F3
# 16 0.6065621 0.004183187  F5
# 17 0.6703478 0.004623089  F1
# 18 0.7408413 0.010218500  F3
# 19 0.8187477 0.033879216  F1
# 20 0.9048468 0.049922582  F1

# %% [markdown]
# # Assigning weight to F1-F5, Depending on category, and evenly spreading out the remaining weight across F1-F5.
# note: I made a change so that the ones near get a little more weight.
# There's 10 shares of uncertainty, the main gets 3, the ones around get 2 each, or 4, and the remaining get 1.
#
# Things here get 3, things one away get 2 or 4, things two or more away gets 1.
# F1: 3(F1) + 2(F2)+ 1(F3-5) = 8
# F2: 3(F2)+ 2(F1)+2(F3) + 1(F4-F5) = 9
# F3: 3(F3)+ 2(F2)+2(F4)+1(F5)+ 1(F1) = 9
# F4: 3(F4)+ 2(F5)+2(F3) + 1(F2-F1) = 9
# F5: 3(F5) + 2(F4) + 1(F3-5) = 8

# %%
library(dst)
fat_data2 <- fat_data|>
  rowwise()|>
  mutate(array_col = case_when(
    Fatality_Category == "F1" ~ list(c(final_weight +(1 - final_weight)/5,
                                       (1 - final_weight)/5,
                                      (1 - final_weight)/5 ,
                                       (1 - final_weight)/5,
                                       (1 - final_weight)/5)),
    Fatality_Category == "F2" ~ list(c((1 - final_weight)/5 , 
                                       final_weight+(1 - final_weight)/5,
                                       (1 - final_weight)/5 ,
                                       (1 - final_weight)/5 ,
                                        (1 - final_weight)/5)),
    Fatality_Category == "F3" ~ list(c((1 - final_weight)/5 ,
                                       (1 - final_weight)/5 , 
                                       final_weight+(1 - final_weight)/5,
                                       (1 - final_weight)/5 ,
                                       (1 - final_weight)/5)),
    Fatality_Category == "F4" ~ list(c((1 - final_weight)/5, 
                                       (1 - final_weight)/5 , 
                                       (1 - final_weight)/5,  
                                       final_weight+(1 - final_weight)/5,
                                       (1 - final_weight)/5 )),
    Fatality_Category == "F5" ~ list(c( (1 - final_weight)/5, 
                                         (1 - final_weight)/5,   
                                       (1 - final_weight)/5 ,   
                                       (1 - final_weight)/5 ,
                                       final_weight+(1 - final_weight)/5))
  ))|>
  ungroup()

#fat_data2$`array_col`

array_matrix <- do.call(rbind, fat_data2$array_col)
#array_matrix

weights_df <- as.data.frame(array_matrix) %>%
  setNames(paste0("Position_", seq_len(ncol(array_matrix))))  # Rename columns

# Step 3: Add an ID column if needed for tracking
weights_df <- weights_df %>%
  mutate(Row_ID = row_number()) %>%
  relocate(Row_ID)
weights_df
#add code under this
#fat_data2
# Out:
#    Row_ID Position_1 Position_2 Position_3 Position_4 Position_5
# 1   1     0.1993242  0.1993242  0.1993242  0.1993242  0.2027031
# 2   2     0.1914114  0.1914114  0.1914114  0.2343543  0.1914114
# 3   3     0.1797785  0.1797785  0.2808861  0.1797785  0.1797785
# 4   4     0.1737753  0.1737753  0.1737753  0.3048989  0.1737753
# 5   5     0.1778221  0.1778221  0.1778221  0.2887116  0.1778221
# 6   6     0.1877449  0.1877449  0.1877449  0.2490203  0.1877449
# 7   7     0.1775296  0.1775296  0.2898816  0.1775296  0.1775296
# 8   8     0.1836712  0.1836712  0.2653152  0.1836712  0.1836712
# 9   9     0.1766907  0.1766907  0.2932372  0.1766907  0.1766907
# 10 10     0.1867043  0.1867043  0.1867043  0.2531830  0.1867043
# 11 11     0.1820918  0.1820918  0.1820918  0.2716328  0.1820918
# 12 12     0.1736114  0.1736114  0.3055543  0.1736114  0.1736114
# 13 13     0.1186785  0.5252861  0.1186785  0.1186785  0.1186785
# 14 14     0.1938018  0.2247926  0.1938018  0.1938018  0.1938018
# 15 15     0.1972600  0.1972600  0.2109599  0.1972600  0.1972600
# 16 16     0.1991634  0.1991634  0.1991634  0.1991634  0.2033465
# 17 17     0.2036985  0.1990754  0.1990754  0.1990754  0.1990754
# 18 18     0.1979563  0.1979563  0.2081748  0.1979563  0.1979563
# 19 19     0.2271034  0.1932242  0.1932242  0.1932242  0.1932242
# 20 20     0.2399381  0.1900155  0.1900155  0.1900155  0.1900155

# %% [markdown]
# # Some Extra processing to make the the array file work.

# %%
weights <- fat_data2 
  #unnest_wider(array_col, names_sep = "_")
str(weights$array_col[[1]])

weights <- weights|>
   mutate(
    array_str = map_chr(array_col, ~ paste(round(.x, 3), collapse = ","))
  )

tt1 <- rbind(
  c(1, 0, 0, 0, 0, 0),  # F1
  c(0, 0, 0, 0, 0, 1),  # F6
  c(1, 1, 1, 1, 1, 1)   # Full frame
)# the frame of discerment or whatever
m1 <- weights$array_col
#m1


library(purrr)

# A small helper to build a bca from a length-6 weight vector
bca_from_vector <- function(v, cnames = c("F1","F2","F3","F4","F5"),
                            varname = "FatalityRate") {
  # Identify which positions in 'v' are non-zero
  non_zero_idx <- which(v != 0)

  # If all are zero (unlikely, but just in case), return a "vacuous" BCA?
  if (length(non_zero_idx) == 0) {
    stop("All-zero vector -- cannot create a BCA.")
  }

  # Build a 'tt' matrix: each row corresponds to a subset with 1 in the relevant column(s)
  # BUT in your scenario, each subset is just a single element: F1 or F2 or ...
  # So each focal element is a row of zeros except 1 in that focal element's column.
  # We'll do one row per non-zero element.
  tt_list <- lapply(non_zero_idx, function(i) {
    rowvec <- rep(0, 5)
    rowvec[i] <- 1
    rowvec
  })
  tt <- do.call(rbind, tt_list)  # combine rows

  # The masses are exactly the non-zero entries of v
  m <- v[non_zero_idx]

  # Create the bca object
  bca(
    tt     = tt, 
    m      = m,
    cnames = cnames,
    varnames = varname
  )
}

weights_bca <- weights %>%
  mutate(
    bca_obj = map(array_col, ~ bca_from_vector(.x))
  )
weights_bca$bca_obj

#str(weights_bca)
# Out:
#  num [1:5] 0.199 0.199 0.199 0.199 0.203
# [[1]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e51361d30>
#
# $spec
#    specnb      mass
# F1      1 0.1993242
# F2      2 0.1993242
# F3      3 0.1993242
# F4      4 0.1993242
# F5      5 0.2027031
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[2]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e58d94d88>
#
# $spec
#    specnb      mass
# F1      1 0.1914114
# F2      2 0.1914114
# F3      3 0.1914114
# F4      4 0.2343543
# F5      5 0.1914114
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[3]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e58db0dc0>
#
# $spec
#    specnb      mass
# F1      1 0.1797785
# F2      2 0.1797785
# F3      3 0.2808861
# F4      4 0.1797785
# F5      5 0.1797785
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[4]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e58d63df8>
#
# $spec
#    specnb      mass
# F1      1 0.1737753
# F2      2 0.1737753
# F3      3 0.1737753
# F4      4 0.3048989
# F5      5 0.1737753
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[5]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e58984e30>
#
# $spec
#    specnb      mass
# F1      1 0.1778221
# F2      2 0.1778221
# F3      3 0.1778221
# F4      4 0.2887116
# F5      5 0.1778221
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[6]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e589b0e68>
#
# $spec
#    specnb      mass
# F1      1 0.1877449
# F2      2 0.1877449
# F3      3 0.1877449
# F4      4 0.2490203
# F5      5 0.1877449
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[7]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e58971ea0>
#
# $spec
#    specnb      mass
# F1      1 0.1775296
# F2      2 0.1775296
# F3      3 0.2898816
# F4      4 0.1775296
# F5      5 0.1775296
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[8]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e5882aed8>
#
# $spec
#    specnb      mass
# F1      1 0.1836712
# F2      2 0.1836712
# F3      3 0.2653152
# F4      4 0.1836712
# F5      5 0.1836712
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[9]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e571b2f10>
#
# $spec
#    specnb      mass
# F1      1 0.1766907
# F2      2 0.1766907
# F3      3 0.2932372
# F4      4 0.1766907
# F5      5 0.1766907
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[10]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e5890af48>
#
# $spec
#    specnb      mass
# F1      1 0.1867043
# F2      2 0.1867043
# F3      3 0.1867043
# F4      4 0.2531830
# F5      5 0.1867043
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[11]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e57db2f80>
#
# $spec
#    specnb      mass
# F1      1 0.1820918
# F2      2 0.1820918
# F3      3 0.1820918
# F4      4 0.2716328
# F5      5 0.1820918
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[12]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e58145f98>
#
# $spec
#    specnb      mass
# F1      1 0.1736114
# F2      2 0.1736114
# F3      3 0.3055543
# F4      4 0.1736114
# F5      5 0.1736114
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[13]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e58169fd0>
#
# $spec
#    specnb      mass
# F1      1 0.1186785
# F2      2 0.5252861
# F3      3 0.1186785
# F4      4 0.1186785
# F5      5 0.1186785
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[14]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e57c3d028>
#
# $spec
#    specnb      mass
# F1      1 0.1938018
# F2      2 0.2247926
# F3      3 0.1938018
# F4      4 0.1938018
# F5      5 0.1938018
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[15]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e57529040>
#
# $spec
#    specnb      mass
# F1      1 0.1972600
# F2      2 0.1972600
# F3      3 0.2109599
# F4      4 0.1972600
# F5      5 0.1972600
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[16]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e5748f078>
#
# $spec
#    specnb      mass
# F1      1 0.1991634
# F2      2 0.1991634
# F3      3 0.1991634
# F4      4 0.1991634
# F5      5 0.2033465
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[17]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e574b50b0>
#
# $spec
#    specnb      mass
# F1      1 0.2036985
# F2      2 0.1990754
# F3      3 0.1990754
# F4      4 0.1990754
# F5      5 0.1990754
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[18]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e5745a0e8>
#
# $spec
#    specnb      mass
# F1      1 0.1979563
# F2      2 0.1979563
# F3      3 0.2081748
# F4      4 0.1979563
# F5      5 0.1979563
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[19]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e57405120>
#
# $spec
#    specnb      mass
# F1      1 0.2271034
# F2      2 0.1932242
# F3      3 0.1932242
# F4      4 0.1932242
# F5      5 0.1932242
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"
#
# [[20]]
# $con
# [1] 0
#
# $tt
#    F1 F2 F3 F4 F5
# F1  1  0  0  0  0
# F2  0  1  0  0  0
# F3  0  0  1  0  0
# F4  0  0  0  1  0
# F5  0  0  0  0  1
#
# $qq
# function (x)
# {
#     q <- 0
#     for (i in 1:nrow(tt)) {
#         if (all(tt[i, ] - x >= 0)) {
#             q <- q + m[i]
#         }
#     }
#     return(q)
# }
# <bytecode: 0x0000018e4ee275b8>
# <environment: 0x0000018e57431158>
#
# $spec
#    specnb      mass
# F1      1 0.2399381
# F2      2 0.1900155
# F3      3 0.1900155
# F4      4 0.1900155
# F5      5 0.1900155
#
# $infovar
#      varnb size
# [1,]     0    5
#
# $varnames
# [1] "FatalityRate"
#
# $valuenames
# $valuenames$FatalityRate
# [1] "F1" "F2" "F3" "F4" "F5"
#
#
# $ssnames
# $ssnames[[1]]
# [1] "F1"
#
# $ssnames[[2]]
# [1] "F2"
#
# $ssnames[[3]]
# [1] "F3"
#
# $ssnames[[4]]
# [1] "F4"
#
# $ssnames[[5]]
# [1] "F5"
#
#
# $inforel
#      relnb depth
# [1,]     0     0
#
# attr(,"class")
# [1] "list"    "bcaspec"

# %% [markdown]
# # I have no Idea I chatgpted this part but it works

# %%
combined_unnorm <- reduce(
  weights_bca$bca_obj,
  ~ dsrwon(.x, .y)     # .x is the "accumulator", .y is the next BCA
)
#combined_unnorm

# Now 'combined_unnorm' is a bcaspec representing the *unnormalized* combination.

combined_bca <- nzdsr(combined_unnorm)
#combined_bca

res_belplau <- belplau(combined_bca)
res_belplau
# Out:
#    bel        disbel    unc          plau       rplau
# F1 0.05215381 0.9491255 -0.001279294 0.05087452 0.05367381
# F2 0.17631594 0.8249634 -0.001279294 0.17503665 0.21250459
# F3 0.41575949 0.5855198 -0.001279294 0.41448020 0.70943420
# F4 0.32139089 0.6798884 -0.001279294 0.32011160 0.47171721
# F5 0.03565916 0.9656201 -0.001279294 0.03437987 0.03565116
